# %%
import matplotlib.pyplot as plt 
import quandl

# %%
quandl.ApiConfig.api_key ="PDvy6a-Ay5gmtgyQwyLV"

# %%
data = quandl.get("CFTC/13874U_FO_L_OLD_CR")  # Retrieve S&P500

# %%
data.plot() 
plt.show()

# %%
#df = pd.read_clipboard()

# %%
df.head()
# Out:
#            Date    Open    High     Low  Close*  Adj Close**       Volume
# 0  May 26, 2023  761.29  765.94  758.95  764.84       764.84  147,624,985
# 1  May 25, 2023  762.06  764.78  756.94  762.16       762.16  165,712,800
# 2  May 24, 2023  773.43  773.68  767.33  768.05       768.05  128,804,700
# 3  May 23, 2023  776.58  776.58  771.93  773.06       773.06  137,650,500
# 4  May 22, 2023  789.80  789.80  777.94  778.59       778.59  134,853,500

# %%
df.to_csv("Consumer_Staples.csv")

# %%
Consumer_Staples = pd.read_csv("Consumer_Staples.csv")

# %%
Consumer_Staples.head()
# Out:
#    Unnamed: 0          Date    Open    High     Low  Close*  Adj Close**  \
# 0           0  May 26, 2023  761.29  765.94  758.95  764.84       764.84
# 1           1  May 25, 2023  762.06  764.78  756.94  762.16       762.16
# 2           2  May 24, 2023  773.43  773.68  767.33  768.05       768.05
# 3           3  May 23, 2023  776.58  776.58  771.93  773.06       773.06
# 4           4  May 22, 2023  789.80  789.80  777.94  778.59       778.59
#
#         Volume
# 0  147,624,985
# 1  165,712,800
# 2  128,804,700
# 3  137,650,500
# 4  134,853,500

# %%
df1 = pd.read_clipboard()

# %%
df1.head()
# Out:
#            Date    Open    High     Low  Close*  Adj Close**       Volume
# 0  May 26, 2023  604.77  610.46  599.85  602.51       602.51  138,167,500
# 1  May 25, 2023  616.43  616.43  599.83  604.77       604.77  162,236,500
# 2  May 24, 2023  613.23  621.22  611.35  616.43       616.43  137,879,400
# 3  May 23, 2023  606.94  620.61  606.94  613.23       613.23  139,637,800
# 4  May 22, 2023  609.30  613.02  606.52  606.94       606.94  136,684,400

# %%
df1.to_csv("Energy.csv")

# %%
Energy = pd.read_csv("Energy.csv")

# %%
Energy.head()
# Out:
#    Unnamed: 0          Date    Open    High     Low  Close*  Adj Close**  \
# 0           0  May 26, 2023  604.77  610.46  599.85  602.51       602.51
# 1           1  May 25, 2023  616.43  616.43  599.83  604.77       604.77
# 2           2  May 24, 2023  613.23  621.22  611.35  616.43       616.43
# 3           3  May 23, 2023  606.94  620.61  606.94  613.23       613.23
# 4           4  May 22, 2023  609.30  613.02  606.52  606.94       606.94
#
#         Volume
# 0  138,167,500
# 1  162,236,500
# 2  137,879,400
# 3  139,637,800
# 4  136,684,400

# %%
df2 = pd.read_clipboard()

# %%
df2.head()
# Out:
#            Date    Open    High     Low  Close*  Adj Close**       Volume
# 0  May 26, 2023  207.37  211.14  206.53  210.92       210.92  307,898,400
# 1  May 25, 2023  206.48  209.82  206.39  207.37       207.37  399,977,700
# 2  May 24, 2023  207.14  207.45  205.20  206.48       206.48  253,331,100
# 3  May 23, 2023  210.85  210.90  207.73  207.73       207.73  272,091,700
# 4  May 22, 2023  208.37  212.50  208.37  210.85       210.85  263,667,000

# %%
df2.to_csv("Communication_Services.csv")

# %%
Communication_Services = pd.read_csv("Communication_Services.csv")

# %%
Communication_Services.head()
# Out:
#    Unnamed: 0          Date    Open    High     Low  Close*  Adj Close**  \
# 0           0  May 26, 2023  207.37  211.14  206.53  210.92       210.92
# 1           1  May 25, 2023  206.48  209.82  206.39  207.37       207.37
# 2           2  May 24, 2023  207.14  207.45  205.20  206.48       206.48
# 3           3  May 23, 2023  210.85  210.90  207.73  207.73       207.73
# 4           4  May 22, 2023  208.37  212.50  208.37  210.85       210.85
#
#         Volume
# 0  307,898,400
# 1  399,977,700
# 2  253,331,100
# 3  272,091,700
# 4  263,667,000

# %%
df3 = pd.read_clipboard()

# %%
df3.head()
# Out:
#            Date    Open    High     Low  Close*  Adj Close**       Volume
# 0  May 26, 2023  826.17  833.27  825.80  830.39       830.39  153,779,000
# 1  May 25, 2023  821.42  826.06  817.01  824.03       824.03  193,548,900
# 2  May 24, 2023  829.92  829.93  820.46  821.53       821.53  174,945,800
# 3  May 23, 2023  838.55  840.97  830.95  832.07       832.07  180,217,300
# 4  May 22, 2023  843.31  847.44  835.76  842.45       842.45  159,481,000

# %%
df3.to_csv("Industrials.csv")

# %%
Industrials = pd.read_csv("Industrials.csv")

# %%
Industrials.head()
# Out:
#    Unnamed: 0          Date    Open    High     Low  Close*  Adj Close**  \
# 0           0  May 26, 2023  826.17  833.27  825.80  830.39       830.39
# 1           1  May 25, 2023  821.42  826.06  817.01  824.03       824.03
# 2           2  May 24, 2023  829.92  829.93  820.46  821.53       821.53
# 3           3  May 23, 2023  838.55  840.97  830.95  832.07       832.07
# 4           4  May 22, 2023  843.31  847.44  835.76  842.45       842.45
#
#         Volume
# 0  153,779,000
# 1  193,548,900
# 2  174,945,800
# 3  180,217,300
# 4  159,481,000
