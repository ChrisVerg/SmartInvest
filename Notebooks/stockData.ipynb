# %% [markdown]
# # Data access from Data folder

# %%
import pandas as pd

# %%
data_test = pd.read_csv('../Data/data.csv')

# %%
data_test.head()
# Out:
#          Date    Value
# 0  2022-01-01  4910.38
# 1  2022-01-31  4515.55
# 2  2022-02-01  4719.29
# 3  2022-02-28  4373.94
# 4  2022-03-01  4610.17

# %% [markdown]
# # Data Import from quandl

# %%
import matplotlib.pyplot as plt 
import quandl 
data = quandl.get("MULTPL/SP500_INFLADJ_MONTH", start_date="2022-01-01", end_date="2023-01-01", api_key="6eHMwALMyhv5Mz-xEPRB") 
data.plot() 
plt.show()

# %%
# Test data
data_test.to_csv('../Data/data_test.csv')
