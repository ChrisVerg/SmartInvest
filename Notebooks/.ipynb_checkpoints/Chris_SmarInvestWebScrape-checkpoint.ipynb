# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">
#
# # Data Scraping for SmartInvest
#
# - [API Reference]()
# - [Reference](https://www.cnbc.com/)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">

# %% [markdown]
# ### Table of Contents <a class="anchor" id="PSCRAPE_toc"></a>
#
# * [Table of Contents](#PSCRAPE_toc)
#     * [1. Abstract](#PSCRAPE_page_1)
#     * [2. Imported Libraries](#PSCRAPE_page_2)
#     * [3. Import Data](#PSCRAPE_page_3)
#     * [4. Data Compiler](#PSCRAPE_page_4)
#     * [5. Data Collection Automation](#PSCRAPE_page_5)
#     * [6. EDA of Textual Data](#PSCRAPE_page_6)
#     * [7. Cleaning the Column Names](#PSCRAPE_page_7)
#     * [8. Creating a new Cleaned Dataset](#PSCRAPE_page_8)
#     * [9. Counting Columns](#PSCRAPE_page_9)
#     * [10. Get Info about the Dataset](#PSCRAPE_page_10)
#     * [11. Get Descriptive Statistics about the Dataset](#PSCRAPE_page_11)
#     * [12. Counting Rows and Removing any NANs](#PSCRAPE_page_12)
#     * [13. Correlation Analysis](#PSCRAPE_page_13)
#     * [14. Principal Component Analysis (PCA)](#PSCRAPE_page_14)
#     * [15. Group Comparison](#PSCRAPE_page_15)
#     * [16. TBD](#PSCRAPE_page_16)
#     * [17. Groupby Function](#PSCRAPE_page_17)

# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">
#
# # Page 1 - Abstract <a class="anchor" id="PSCRAPE_page_1"></a>
#
# [Back to Top](#PSCRAPE_toc)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">

# %% [markdown]
# >This abstract presents the utilization of the BeautifulSoup Python library to web scrape textual data from the CNBC financial news outlet. The scraped data serves as the foundation for developing a sentiment indicator aimed at stock market analysis. By extracting relevant financial news articles and employing sentiment analysis techniques, sentiment scores are assigned to the text, indicating whether the sentiment expressed in the articles is positive, negative, or neutral. These sentiment scores can be aggregated over time to create a sentiment indicator, providing valuable insights into market sentiment and assisting traders and investors in making informed decisions.

# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">
#
# # Page 2 - Imported Libraries<a class="anchor" id="PSCRAPE_page_2"></a>
#
# [Back to Top](#PSCRAPE_toc)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">
#
# # Page 3 - Import Data<a class="anchor" id="PSCRAPE_page_3"></a>
#
# [Back to Top](#PSCRAPE_toc)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">

# %% [markdown]
# ## Primary Headline

# %%
URL = "https://www.cnbc.com/"

# %%
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
# This pulls pulls the URL and Main Headline Data
soup.find('div', class_="FeaturedCard-packagedCardTitle")

# %%
result = soup.find_all('div', class_="FeaturedCard-packagedCardTitle")

# %%
for headline in soup.find_all('div', class_="FeaturedCard-contentText"):
    links = headline.find_all("a")
    for link in links:
        print(link.text.strip())
# Out:
# Debt ceiling bill faces a tough path in the House as GOP opposition grows

# %% [markdown]
# # Secondary Headlines

# %%
import requests
from bs4 import BeautifulSoup

# %%
URL = "https://www.cnbc.com/"

# %%
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
soup.find('div', class_="SecondaryCard-headline")
# Out:
# <div class="SecondaryCard-headline"><a href="https://www.cnbc.com/2023/05/30/nvidia-on-track-to-hit-1-trillion-market-cap-when-market-opens.html" title="Nvidia hits $1 trillion market cap">Nvidia hits $1 trillion market cap</a></div>

# %%
result_secondary = soup.find_all('div', class_="SecondaryCard-headline")

# %%
for headline in soup.find_all('div', class_="SecondaryCard-headline"):
    links = headline.find_all("a")
    for link in links:
        print(link.text.strip())
# Out:
# Nvidia hits $1 trillion market cap
# Home price declines may be over, S&P Case-Shiller says

# %% [markdown]
# # Latest News Headlines

# %%
import requests
from bs4 import BeautifulSoup

# %%
URL = "https://www.cnbc.com/"

# %%
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
soup.find('div', class_="LatestNews-headlineWrapper")
# Out:
# <div class="LatestNews-headlineWrapper"><span class="LatestNews-wrapper"><time class="LatestNews-timestamp">23 Min Ago</time></span><a class="ProPill-proPillLink" data-type="pro-button" href="/pro/"><img alt="CNBC Pro" class="LatestNews-proPill ProPill-proPill" src="https://static-redesign.cnbcfm.com/dist/3390fc2824fa58d008fd.svg"/></a><a class="LatestNews-headline" href="https://www.cnbc.com/2023/05/30/bernstein-gives-an-under-the-radar-way-to-play-the-transition-to-clean-energy.html" title="Bernstein gives an under-the-radar way to play the transition to clean energy">Bernstein gives an under-the-radar way to play the transition to clean energy</a></div>

# %%
result_secondary = soup.find_all('div', class_="LatestNews-headlineWrapper")

# %%
for headline in soup.find_all('div', class_="LatestNews-headlineWrapper"):
    links = headline.find_all("a")
    for link in links:
        print(link.text.strip())
# Out:
# Bernstein gives an under-the-radar way to play the transition to clean energy
# Stocks making the biggest moves midday: Nvidia, Tesla, Coinbase and more
#
# Market focus will shift back to earnings, says Fundstrat's Tom Lee
# Damar Hamlin on how he made the decision to play football in the NFL again
#
# Why this chip stock could be the next Nvidia
#
# Two Club stocks get Wall Street upgrades, sending shares higher
# Debt ceiling deal would push student loan borrowers into repayment by fall
# ChatGPT cited "bogus" cases for a New York federal court filing
# Stablecoin giant Tether to mine bitcoin in Uruguay using renewable energy
#
# Cathie Wood's Ark Invest misses out on Nvidia's powerful rally
# 35-year-old who makes over $5K/month in passive income on her best career advice
# Theranos founder Elizabeth Holmes set to report to prison Tuesday
# Bitcoin rises as investors await vote on tentative debt ceiling agreement
#
# Chart analysts see market correction coming after brief debt deal euphoria
#
# Jim Cramer's top 10 things to watch in the stock market Tuesday
#
# RBC raises year-end stock market forecast, sees buying opportunity in small caps
# Debt ceiling bill faces a tough path in the House as GOP opposition grows
# Memorial Day air travel tops 2019 levels as consumers shell out for trips
#
# We are trimming a couple of our tech stocks that have been riding the wave of AI
# Home price declines may be over, S&P Case-Shiller says
#
# Tuesday's biggest analyst calls: Nvidia, Tesla, Ford, Wayfair, Coinbase, Disney
# Nvidia hits $1 trillion market cap
# Stocks making the biggest premarket moves: ChargePoint, Ford, Nvidia and more
# With emergency savings down and credit card balances up, these 3 steps may help
# Tesla shares rise as Elon Musk meets with China's foreign minister
#
# Atlantic Equities says Coinbase is the 'best expression of crypto'
#
# BofA says this 'best-in-class' electric vehicle charging stock could surge 65%
# 5 things to know before the stock market opens Tuesday
#
# Roth sees more than 20% upside for Boston Beer heading into summer
# China's disappointing rebound could bring in more stimulus, economists say

# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">
#
# # Page 4 - Headline Compiler <a class="anchor" id="PSCRAPE_page_4"></a>
#
# [Back to Top](#PSCRAPE_toc)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">

# %% [markdown]
# # Primary Headline Compiler

# %%
# Automate Collection 
import schedule
import time

import pandas as pd
import csv
import requests
from bs4 import BeautifulSoup
url = "https://www.cnbc.com/"

def append_data_to_csv(url):
    file_path = "../Data/PrimaryHeadline_CV.csv"

    # Fetch the data from the URL
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")

    # Extract the headlines
    headlines = set()
    for headline in soup.find_all('div', class_="FeaturedCard-contentText"):
        links = headline.find_all("a")
        for link in links:
            headlines.add(link.text.strip())

    # Append the data to the CSV file
    with open(file_path, "a", newline="") as file:
        writer = csv.writer(file)

        # Check for duplicates before writing
        existing_headlines = set()
        try:
            with open(file_path, "r") as existing_file:
                existing_data = csv.reader(existing_file)
                for row in existing_data:
                    existing_headlines.update(row)
        except FileNotFoundError:
            pass

        new_headlines = headlines - existing_headlines
        if new_headlines:
            writer.writerow(new_headlines)
            
# Schedule the interval for collection
#schedule.every(2).hours.do(append_data_to_csv, url="https://www.cnbc.com/")


# while True:
    # Example usage
URL = "https://www.cnbc.com/"
append_data_to_csv(URL)

# %%
data_test = pd.read_csv('../Data/PrimaryHeadline_CV.csv')

# %%
data_test
# Out:
#   Debt ceiling negotiators make progress on spending, but still have 'major issues'
# 0  Treasury now says it could run out of money Ju...
# 1  Biden says he's 'very optimistic' about a debt...
# 2  Debt ceiling bill faces a tough path in the Ho...

# %% [markdown]
# # Secondary Headline Complier

# %%
# Automate Collection 
import schedule
import time

import pandas as pd
import csv
import requests
from bs4 import BeautifulSoup
url = "https://www.cnbc.com/"

def append_data_to_csv(url):
    file_path = "../Data/SecondaryHeadline_CV.csv"

    # Fetch the data from the URL
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")

    # Extract the headlines
    headlines = set()
    for headline in soup.find_all('div', class_="SecondaryCard-headline"):
        links = headline.find_all("a")
        for link in links:
            headlines.add(link.text.strip())

    # Append the data to the CSV file
    with open(file_path, "a", newline="") as file:
        writer = csv.writer(file)

        # Check for duplicates before writing
        existing_headlines = set()
        try:
            with open(file_path, "r") as existing_file:
                existing_data = csv.reader(existing_file)
                for row in existing_data:
                    existing_headlines.update(row)
        except FileNotFoundError:
            pass

        new_headlines = headlines - existing_headlines
        if new_headlines:
            writer.writerow(new_headlines)
            
# Schedule the interval for collection
#schedule.every(2).hours.do(append_data_to_csv, url="https://www.cnbc.com/")


#while True:
    # Example usage
URL = "https://www.cnbc.com/"
append_data_to_csv(URL)

# %%
data_test1 = pd.read_csv('../Data/SecondaryHeadline_CV.csv')

# %%
data_test1
# Out:
#   JPMorgan Chase cut about 500 technology and operations jobs this week, sources say
# 0  JPMorgan Chase cut about 500 jobs this week, i...                                  \
# 1  The tech trade is back, driven by A.I. craze a...
# 2  Home price declines may be over, S&P Case-Shil...
#
#   Dow jumps 300 points as Wall Street grows hopeful that a debt ceiling deal can be reached
# 0                                                NaN
# 1  Stocks rally Friday on hopes for a debt ceilin...
# 2                 Nvidia hits $1 trillion market cap

# %% [markdown]
# # Latest News Headline Compiler

# %%
# Latest News Headlines 
import schedule
import time

# NLP Remove stop words
import nltk
from nltk.corpus import stopwords

import pandas as pd
import csv
import requests
from bs4 import BeautifulSoup
url = "https://www.cnbc.com/"

def preprocess_data(data):
    # Apply any necessary preprocessing steps
    # Remove characters not recognized by UTF-8
    data = data.encode('utf-8', errors='ignore').decode('utf-8')
    
    # For example, convert text to lowercase or capitalize the first letter of each word
    return data.lower()

     # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in data.split() if word.lower() not in stop_words]
    data = ' '.join(words)
    return data

def append_data_to_csv(url):
    file_path = "../Data/LatestHeadline_CV.csv"

    # Fetch the data from the URL
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")

    # Extract the headlines
    headlines = set()
    for headline in soup.find_all('div', class_="LatestNews-headlineWrapper"):
        links = headline.find_all("a")
        for link in links:
            headlines.add(link.text.strip())
            
    processed_headlines = [preprocess_data(headline) for headline in headlines]

    # Append the data to the CSV file
    with open(file_path, "a", newline="") as file:
        writer = csv.writer(file)

        # Check for duplicates before writing
        existing_headlines = set()
        try:
            with open(file_path, "r") as existing_file:
                existing_data = csv.reader(existing_file)
                for row in existing_data:
                    existing_headlines.update(row)
        except FileNotFoundError:
            pass

        new_headlines = set(processed_headlines) - set(existing_headlines)
        if new_headlines:
            writer.writerow(new_headlines)
            
# Schedule the interval for collection
#schedule.every(2).hours.do(append_data_to_csv, url="https://www.cnbc.com/")


#while True:
    # Example usage
URL = "https://www.cnbc.com/"
append_data_to_csv(URL)

# %%
data_test2 = pd.read_csv('../Data/LatestHeadline_CV.csv',encoding='latin-1')

# %%
data_test2
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ï»¿
# NaN                                                companies add, expand tuition assistance so wor... stocks making the biggest moves midday: ford, m... despite all odds, consumers are still traveling... marvell shares soar 25% after the chip firm bea... biden interior advances renewable energy transm... apple and nvidia are in my top 5 holdings. am i... companies are learning gen z isnt the easiest ... heres why it might be time to buy longer-term ... house passes bill blocking student debt forgive... paramount shares pop after bdt capital bets on ... ford's ev charging deal with tesla puts pressur... morgan stanley upgrades this  mining stock that... club name ford teams up with tesla, sending sha... bofa hits spacecraft builder terran orbital wit... taylor swift to metallica: top 10 most in-deman... facebook-giphy sale shows how fear of regulator... ai is the latest buzzword in techbut before in... needham says this stock plays the 'almost perfe... jpmorgan chase cut about 500 tech and operation... how virtual layoffs became the new normal for w... nvidia shares jumped 25% this week  and got ch... these industries could face major disruptions f... a.i. excitement leads to a winning week for nvi... vesting means it can take up to 6 years for wor... is there a 'right' age for kids to be on social... jpmorgan ceo jamie dimon faces deposition in je... 30-year-old billionaire started with a website,... why the pause on student loan payments has been... how this cmo got comfortable embracing his asia...  investors shifted into these gold and small-ca...
# jpmorgan chase cut about 500 jobs this week, in... disney rips desantis bid to disqualify judge in... NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                                                               NaN
# top 10 cheapest places in the u.s. to buy a bea... 3 investing tips as the federal debt ceiling 'x... lower-income consumers pay for wealthy's credit... analysts are pounding the table for these must-... how janie deegan built janie's life-changing ba... the tech trade is back, driven by a.i. craze an... chip stocks amd and nvidia are among the most o... why commercial real estate firms are joining to... how mastercard has outperformed visa               mark cuban calls elon musks twitter algorithm ... next week hints at only short-lived debt deal r... steve adcock: the 3 'stupidest' myths i've hear... marvell technology shares surge after earnings ... treasury says it could run out of money june 5,... microsoft keyboard users are devastated after... japan stocks are on fire this year. why the ral... NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                                                               NaN
# with emergency savings down and credit card bal... memorial day air travel tops 2019 levels as con... theranos founder elizabeth holmes set to report... chart analysts see market correction coming aft... stocks making the biggest moves midday: nvidia,... damar hamlin on how he made the decision to pla... debt ceiling deal would push student loan borro... debt ceiling bill faces a tough path in the hou... bernstein gives an under-the-radar way to play ... bofa says this 'best-in-class' electric vehicle... tuesday's biggest analyst calls: nvidia, tesla,... bitcoin rises as investors await vote on tentat... 5 things to know before the stock market opens ... 35-year-old who makes over $5k/month in passive... stablecoin giant tether to mine bitcoin in urug... cathie wood's ark invest misses out on nvidia's... we are trimming a couple of our tech stocks tha... jim cramer's top 10 things to watch in the stoc... rbc raises year-end stock market forecast, sees... tesla shares rise as elon musk meets with china... market focus will shift back to earnings, says ... chatgpt cited "bogus" cases for a new york fede... roth sees more than 20% upside for boston beer ... two club stocks get wall street upgrades, sendi... atlantic equities says coinbase is the 'best ex... nvidia hits $1 trillion market cap                 why this chip stock could be the next nvidia       china's disappointing rebound could bring in mo... home price declines may be over, s&p case-shill... stocks making the biggest premarket moves: char...                                                NaN

# %% [markdown]
# # All Headlines Compiler

# %%
import schedule
import time

# NLP Remove stop words
import nltk
from nltk.corpus import stopwords

import pandas as pd
import csv
import requests
from bs4 import BeautifulSoup
url = "https://www.cnbc.com/"

def preprocess_data(data):
    # Apply any necessary preprocessing steps
    # Remove characters not recognized by UTF-8
    data = data.encode('utf-8', errors='ignore').decode('utf-8')
    
    # For example, convert text to lowercase or capitalize the first letter of each word
    return data.lower()

     # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in data.split() if word.lower() not in stop_words]
    data = ' '.join(words)
    return data

def append_data_to_csv(url):
    file_path = "../Data/ConsolidatedHeadline_CV.csv"

    # Fetch the data from the URL
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")

    # Extract the headlines
    headlines = set()
    for headline in soup.find_all('div', class_="FeaturedCard-contentText"):
        links = headline.find_all("a")
        for link in links:
            headlines.add(link.text.strip())

    for headline in soup.find_all('div', class_="SecondaryCard-headline"):
        links = headline.find_all("a")
        for link in links:
            headlines.add(link.text.strip())

    for headline in soup.find_all('div', class_="LatestNews-headlineWrapper"):
        links = headline.find_all("a")
        for link in links:
            headlines.add(link.text.strip())

    # Process the headlines
    processed_headlines = [preprocess_data(headline) for headline in headlines]

    # Filter out null values
    non_null_headlines = [headline for headline in processed_headlines if headline]
    
    # Append the data to the CSV file
    with open(file_path, "a", newline="") as file:
        writer = csv.writer(file)

        # Check for duplicates before writing
        existing_headlines = set()
        try:
            with open(file_path, "r") as existing_file:
                existing_data = csv.reader(existing_file)
                for row in existing_data:
                    existing_headlines.update(row)
        except FileNotFoundError:
            pass

        new_headlines = set(processed_headlines) - set(existing_headlines)
        if new_headlines:
            writer.writerow(new_headlines)

            
# Schedule the interval for collection
#schedule.every(2).hours.do(append_data_to_csv, url="https://www.cnbc.com/")


#while True:
    # Example usage
URL = "https://www.cnbc.com/"
append_data_to_csv(URL)

# %%
import pandas as pd

# %%
data_test3 = pd.read_csv('../Data/ConsolidatedHeadline_CV.csv',encoding='latin-1')

# %%
data_test3
# Out:
#                                                  ï»¿
# 0  stocks rally friday on hopes for a debt ceilin...  \
# 1  treasury says it could run out of money june 5...
# 2  top 10 cheapest places in the u.s. to buy a be...
# 3  with emergency savings down and credit card ba...
# 4  bernstein gives an under-the-radar way to play...
# 5  schwarzenegger: 'no one gives a s--- about' cl...
#
#   debt ceiling negotiators make progress on spending, but still have 'major issues'
# 0                                                NaN                                 \
# 1  next week hints at only short-lived debt deal ...
# 2  3 investing tips as the federal debt ceiling '...
# 3  home price declines may be over, s&p case-shil...
# 4  damar hamlin on how he made the decision to pl...
# 5  what is next with debt deal? wall street econo...
#
#   morgan stanley upgrades this  mining stock that can surge more than 20%
# 0                                                NaN                       \
# 1  the tech trade is back, driven by a.i. craze a...
# 2  lower-income consumers pay for wealthy's credi...
# 3  stocks making the biggest premarket moves: cha...
# 4       why this chip stock could be the next nvidia
# 5                                                NaN
#
#   ai is the latest buzzword in techbut before investing, know these 4 terms
# 0                                                NaN                         \
# 1  the tech trade is back, driven by a.i. craze a...
# 2  analysts are pounding the table for these must...
# 3  rbc raises year-end stock market forecast, see...
# 4  schwarzenegger: 'no one gives a s--- about' cl...
# 5                                                NaN
#
#   ford's ev charging deal with tesla puts pressure on gm, other rival automakers
# 0                                                NaN                              \
# 1  treasury now says it could run out of money ju...
# 2  how janie deegan built janie's life-changing b...
# 3  two club stocks get wall street upgrades, send...
# 4  debt limit bill would speed completion of west...
# 5                                                NaN
#
#   marvell shares soar 25% after the chip firm beats on top and bottom line results
# 0                                                NaN                                \
# 1  marvell shares soar 32% after the chip firm be...
# 2  chip stocks amd and nvidia are among the most ...
# 3  china's disappointing rebound could bring in m...
# 4  market focus will shift back to earnings, says...
# 5                                                NaN
#
#   jpmorgan chase cut about 500 jobs this week, including technology and operations roles
# 0                                                NaN                                      \
# 1                                                NaN
# 2  why commercial real estate firms are joining t...
# 3  roth sees more than 20% upside for boston beer...
# 4  theranos founder elizabeth holmes reports to p...
# 5                                                NaN
#
#   dow jumps 300 points as wall street grows hopeful that a debt ceiling deal can be reached
# 0                                                NaN                                         \
# 1                                                NaN
# 2               how mastercard has outperformed visa
# 3                 nvidia hits $1 trillion market cap
# 4  stocks making the biggest moves midday: nvidia...
# 5                                                NaN
#
#   nvidia shares jumped 25% this week  and got cheaper. here's how that happens
# 0                                                NaN                            \
# 1                                                NaN
# 2  biden says he's 'very optimistic' about a debt...
# 3  tesla shares rise as elon musk meets with chin...
# 4                                                NaN
# 5                                                NaN
#
#   disney rips desantis bid to disqualify judge in free speech lawsuit  ...
# 0                                                NaN                   ...  \
# 1                                                NaN                   ...
# 2  mark cuban calls elon musks twitter algorithm ...                   ...
# 3  debt ceiling bill faces a tough path in the ho...                   ...
# 4                                                NaN                   ...
# 5                                                NaN                   ...
#
#   jpmorgan ceo jamie dimon faces deposition in jeffrey epstein lawsuits
# 0                                                NaN                     \
# 1                                                NaN
# 2                                                NaN
# 3  drone attack hits moscow buildings; kyiv endur...
# 4                                                NaN
# 5                                                NaN
#
#   how virtual layoffs became the new normal for workplaces
# 0                                                NaN        \
# 1                                                NaN
# 2                                                NaN
# 3  5 things to know before the stock market opens...
# 4                                                NaN
# 5                                                NaN
#
#   bofa hits spacecraft builder terran orbital with rare double downgrade
# 0                                                NaN                      \
# 1                                                NaN
# 2                                                NaN
# 3  atlantic equities says coinbase is the 'best e...
# 4                                                NaN
# 5                                                NaN
#
#   heres why it might be time to buy longer-term bonds now
# 0                                                NaN       \
# 1                                                NaN
# 2                                                NaN
# 3  bitcoin rises as investors await vote on tenta...
# 4                                                NaN
# 5                                                NaN
#
#   jpmorgan chase cut about 500 jobs this week, including tech and operations roles
# 0                                                NaN                                \
# 1                                                NaN
# 2                                                NaN
# 3  stablecoin giant tether to mine bitcoin in uru...
# 4                                                NaN
# 5                                                NaN
#
#   how this cmo got comfortable embracing his asian identity at work
# 0                                                NaN                 \
# 1                                                NaN
# 2                                                NaN
# 3  jim cramer's top 10 things to watch in the sto...
# 4                                                NaN
# 5                                                NaN
#
#   facebook-giphy sale shows how fear of regulators is slowing m&a market
# 0                                                NaN                      \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   apple and nvidia are in my top 5 holdings. am i still diversified enough?
# 0                                                NaN                         \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   stocks making the biggest moves midday: ford, marvell technology, gap and more
# 0                                                NaN                              \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   companies add, expand tuition assistance so workers can go back to college
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
# [6 rows x 34 columns]

# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">
#
# # Page 5 - Data Collection Automation<a class="anchor" id="PSCRAPE_page_5"></a>
#
# [Back to Top](#PSCRAPE_toc)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">

# %%
# pip install jupyter_scheduler

# %% [markdown]
# ![image.png](attachment:230c30ff-fa60-4e25-98b5-ca691f7d0f81.png)

# %% [markdown]
# # The Jupyter scheduler has not run successfully with the "file_path" using relative path -'../Data/ConsolidatedHeadline_CV.csv'-
# ## At this time I am running the data collection in notebook Automated_Chris_SmartInvestWebScrape.ipynb with the absolute path in the notbook folder.

# %%
# Automate Collection 
import schedule
import time

# NLP Remove stop words
import nltk
from nltk.corpus import stopwords

import pandas as pd
import csv
import requests
from bs4 import BeautifulSoup
url = "https://www.cnbc.com/"

def preprocess_data(data):
    # Apply any necessary preprocessing steps
    # Remove characters not recognized by UTF-8
    data = data.encode('utf-8', errors='ignore').decode('utf-8')
    
    # For example, convert text to lowercase or capitalize the first letter of each word
    return data.lower()

     # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in data.split() if word.lower() not in stop_words]
    data = ' '.join(words)
    return data

def append_data_to_csv(url):
    file_path = ('../Data/ConsolidatedHeadline_CV.csv')

    # Fetch the data from the URL
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")

    # Extract the headlines
    headlines = set()
    for headline in soup.find_all('div', class_="FeaturedCard-contentText"):
        links = headline.find_all("a")
        for link in links:
            headlines.add(link.text.strip())

    for headline in soup.find_all('div', class_="SecondaryCard-headline"):
        links = headline.find_all("a")
        for link in links:
            headlines.add(link.text.strip())

    for headline in soup.find_all('div', class_="LatestNews-headlineWrapper"):
        links = headline.find_all("a")
        for link in links:
            headlines.add(link.text.strip())

    # Process the headlines
    processed_headlines = [preprocess_data(headline) for headline in headlines]

    # Append the data to the CSV file
    with open(file_path, "a", newline="") as file:
        writer = csv.writer(file)

        # Check for duplicates before writing
        existing_headlines = set()
        try:
            with open(file_path, "r") as existing_file:
                existing_data = csv.reader(existing_file)
                for row in existing_data:
                    existing_headlines.update(row)
        except FileNotFoundError:
            pass

        new_headlines = set(processed_headlines) - set(existing_headlines)
        if new_headlines:
            writer.writerow(new_headlines)

            
# Schedule the interval for collection
#schedule.every(2).hours.do(append_data_to_csv, url="https://www.cnbc.com/")


#while True:
    # Example usage
URL = "https://www.cnbc.com/"
append_data_to_csv(URL)

# %%
test = pd.read_csv('../Data/ConsolidatedHeadline_CV.csv',encoding='latin-1')

# %%
test.tail()
# Out:
#                                                  ï»¿
# 0  stocks rally friday on hopes for a debt ceilin...  \
# 1  treasury says it could run out of money june 5...
# 2  top 10 cheapest places in the u.s. to buy a be...
# 3  with emergency savings down and credit card ba...
#
#   debt ceiling negotiators make progress on spending, but still have 'major issues'
# 0                                                NaN                                 \
# 1  next week hints at only short-lived debt deal ...
# 2  3 investing tips as the federal debt ceiling '...
# 3  home price declines may be over, s&p case-shil...
#
#   morgan stanley upgrades this  mining stock that can surge more than 20%
# 0                                                NaN                       \
# 1  the tech trade is back, driven by a.i. craze a...
# 2  lower-income consumers pay for wealthy's credi...
# 3  stocks making the biggest premarket moves: cha...
#
#   ai is the latest buzzword in techbut before investing, know these 4 terms
# 0                                                NaN                         \
# 1  the tech trade is back, driven by a.i. craze a...
# 2  analysts are pounding the table for these must...
# 3  rbc raises year-end stock market forecast, see...
#
#   ford's ev charging deal with tesla puts pressure on gm, other rival automakers
# 0                                                NaN                              \
# 1  treasury now says it could run out of money ju...
# 2  how janie deegan built janie's life-changing b...
# 3  two club stocks get wall street upgrades, send...
#
#   marvell shares soar 25% after the chip firm beats on top and bottom line results
# 0                                                NaN                                \
# 1  marvell shares soar 32% after the chip firm be...
# 2  chip stocks amd and nvidia are among the most ...
# 3  china's disappointing rebound could bring in m...
#
#   jpmorgan chase cut about 500 jobs this week, including technology and operations roles
# 0                                                NaN                                      \
# 1                                                NaN
# 2  why commercial real estate firms are joining t...
# 3  roth sees more than 20% upside for boston beer...
#
#   dow jumps 300 points as wall street grows hopeful that a debt ceiling deal can be reached
# 0                                                NaN                                         \
# 1                                                NaN
# 2               how mastercard has outperformed visa
# 3                 nvidia hits $1 trillion market cap
#
#   nvidia shares jumped 25% this week  and got cheaper. here's how that happens
# 0                                                NaN                            \
# 1                                                NaN
# 2  biden says he's 'very optimistic' about a debt...
# 3  tesla shares rise as elon musk meets with chin...
#
#   disney rips desantis bid to disqualify judge in free speech lawsuit  ...
# 0                                                NaN                   ...  \
# 1                                                NaN                   ...
# 2  mark cuban calls elon musks twitter algorithm ...                   ...
# 3  debt ceiling bill faces a tough path in the ho...                   ...
#
#   jpmorgan ceo jamie dimon faces deposition in jeffrey epstein lawsuits
# 0                                                NaN                     \
# 1                                                NaN
# 2                                                NaN
# 3  drone attack hits moscow buildings; kyiv endur...
#
#   how virtual layoffs became the new normal for workplaces
# 0                                                NaN        \
# 1                                                NaN
# 2                                                NaN
# 3  5 things to know before the stock market opens...
#
#   bofa hits spacecraft builder terran orbital with rare double downgrade
# 0                                                NaN                      \
# 1                                                NaN
# 2                                                NaN
# 3  atlantic equities says coinbase is the 'best e...
#
#   heres why it might be time to buy longer-term bonds now
# 0                                                NaN       \
# 1                                                NaN
# 2                                                NaN
# 3  bitcoin rises as investors await vote on tenta...
#
#   jpmorgan chase cut about 500 jobs this week, including tech and operations roles
# 0                                                NaN                                \
# 1                                                NaN
# 2                                                NaN
# 3  stablecoin giant tether to mine bitcoin in uru...
#
#   how this cmo got comfortable embracing his asian identity at work
# 0                                                NaN                 \
# 1                                                NaN
# 2                                                NaN
# 3  jim cramer's top 10 things to watch in the sto...
#
#   facebook-giphy sale shows how fear of regulators is slowing m&a market
# 0                                                NaN                      \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#   apple and nvidia are in my top 5 holdings. am i still diversified enough?
# 0                                                NaN                         \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#   stocks making the biggest moves midday: ford, marvell technology, gap and more
# 0                                                NaN                              \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#   companies add, expand tuition assistance so workers can go back to college
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
# [4 rows x 34 columns]

# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">
#
# # Page 6 - EDA of Textual Data<a class="anchor" id="PSCRAPE_page_6"></a>
#
# [Back to Top](#PSCRAPE_toc)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">

# %% [markdown]
# ## The First step preapre the data, remove stop words, parse etc...
# ## Next will be to tokenize, count and visualize words

# %%
# Import Packages and notebook set up

import pandas as pd
import string

# Set no max rows and columns to view data
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# Create an object containg the data for data cleaning


text = pd.read_csv("../Data/ConsolidatedHeadline_CV.csv", encoding='latin-1')

# %%
text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 34 columns):
#  #   Column                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                     --------------  -----
#  0   ï»¿                                                                                        23 non-null     object
#  1   debt ceiling negotiators make progress on spending, but still have 'major issues'          20 non-null     object
#  2   morgan stanley upgrades this  mining stock that can surge more than 20%                    14 non-null     object
#  3   ai is the latest buzzword in techbut before investing, know these 4 terms                  11 non-null     object
#  4   ford's ev charging deal with tesla puts pressure on gm, other rival automakers             11 non-null     object
#  5   marvell shares soar 25% after the chip firm beats on top and bottom line results           9 non-null      object
#  6   jpmorgan chase cut about 500 jobs this week, including technology and operations roles     7 non-null      object
#  7   dow jumps 300 points as wall street grows hopeful that a debt ceiling deal can be reached  5 non-null      object
#  8   nvidia shares jumped 25% this week  and got cheaper. here's how that happens               4 non-null      object
#  9   disney rips desantis bid to disqualify judge in free speech lawsuit                        4 non-null      object
#  10  is there a 'right' age for kids to be on social media? here's what an expert says          4 non-null      object
#  11  investors shifted into these gold and small-cap etfs this week                             4 non-null      object
#  12  vesting means it can take up to 6 years for workers to own their 401(k) match              3 non-null      object
#  13  a.i. excitement leads to a winning week for nvidia and other tech stocks                   3 non-null      object
#  14  despite all odds, consumers are still traveling this summer. how to play it                2 non-null      object
#  15  taylor swift to metallica: top 10 most in-demand artists of summer                         2 non-null      object
#  16  companies are learning gen z isnt the easiest generation to work with                      2 non-null      object
#  17  club name ford teams up with tesla, sending shares soaring                                 2 non-null      object
#  18  paramount shares pop after bdt capital bets on the media giant's key shareholder           2 non-null      object
#  19  biden interior advances renewable energy transmission projects in nevada                   2 non-null      object
#  20  needham says this stock plays the 'almost perfect marriage' between a.i., crypto           2 non-null      object
#  21  30-year-old billionaire started with a website, sewing kit and pizza hut salary            2 non-null      object
#  22  why the pause on student loan payments has been a win for public servants                  2 non-null      object
#  23  house passes bill blocking student debt forgivenesswhat borrowers need to know             2 non-null      object
#  24  jpmorgan ceo jamie dimon faces deposition in jeffrey epstein lawsuits                      2 non-null      object
#  25  how virtual layoffs became the new normal for workplaces                                   2 non-null      object
#  26  bofa hits spacecraft builder terran orbital with rare double downgrade                     2 non-null      object
#  27  heres why it might be time to buy longer-term bonds now                                    2 non-null      object
#  28  jpmorgan chase cut about 500 jobs this week, including tech and operations roles           2 non-null      object
#  29  how this cmo got comfortable embracing his asian identity at work                          2 non-null      object
#  30  facebook-giphy sale shows how fear of regulators is slowing m&a market                     1 non-null      object
#  31  apple and nvidia are in my top 5 holdings. am i still diversified enough?                  1 non-null      object
#  32  stocks making the biggest moves midday: ford, marvell technology, gap and more             1 non-null      object
#  33  companies add, expand tuition assistance so workers can go back to college                 0 non-null      float64
# dtypes: float64(1), object(33)
# memory usage: 6.2+ KB

# %%
# Removeing Null Values

text_Nonull = text.dropna()

# %%
# converting object to string

text_string = str(text_Nonull)

# %%
text_string
# Out:
# "Empty DataFrame\nColumns: [ï»¿, debt ceiling negotiators make progress on spending, but still have 'major issues', morgan stanley upgrades this  mining stock that can surge more than 20%, ai is the latest buzzword in techbut before investing, know these 4 terms, ford's ev charging deal with tesla puts pressure on gm, other rival automakers, marvell shares soar 25% after the chip firm beats on top and bottom line results, jpmorgan chase cut about 500 jobs this week, including technology and operations roles, dow jumps 300 points as wall street grows hopeful that a debt ceiling deal can be reached, nvidia shares jumped 25% this week  and got cheaper. here's how that happens, disney rips desantis bid to disqualify judge in free speech lawsuit, is there a 'right' age for kids to be on social media? here's what an expert says, investors shifted into these gold and small-cap etfs this week, vesting means it can take up to 6 years for workers to own their 401(k) match, a.i. excitement leads to a winning week for nvidia and other tech stocks, despite all odds, consumers are still traveling this summer. how to play it, taylor swift to metallica: top 10 most in-demand artists of summer, companies are learning gen z isnt the easiest generation to work with, club name ford teams up with tesla, sending shares soaring, paramount shares pop after bdt capital bets on the media giant's key shareholder, biden interior advances renewable energy transmission projects in nevada, needham says this stock plays the 'almost perfect marriage' between a.i., crypto, 30-year-old billionaire started with a website, sewing kit and pizza hut salary, why the pause on student loan payments has been a win for public servants, house passes bill blocking student debt forgivenesswhat borrowers need to know, jpmorgan ceo jamie dimon faces deposition in jeffrey epstein lawsuits, how virtual layoffs became the new normal for workplaces, bofa hits spacecraft builder terran orbital with rare double downgrade, heres why it might be time to buy longer-term bonds now, jpmorgan chase cut about 500 jobs this week, including tech and operations roles, how this cmo got comfortable embracing his asian identity at work, facebook-giphy sale shows how fear of regulators is slowing m&a market, apple and nvidia are in my top 5 holdings. am i still diversified enough?, stocks making the biggest moves midday: ford, marvell technology, gap and more, companies add, expand tuition assistance so workers can go back to college]\nIndex: []"

# %%
# Convert text to lower case

lower_case = text_string.lower()

# %%
lower_case
# Out:
# "empty dataframe\ncolumns: [ï»¿, debt ceiling negotiators make progress on spending, but still have 'major issues', morgan stanley upgrades this  mining stock that can surge more than 20%, ai is the latest buzzword in techbut before investing, know these 4 terms, ford's ev charging deal with tesla puts pressure on gm, other rival automakers, marvell shares soar 25% after the chip firm beats on top and bottom line results, jpmorgan chase cut about 500 jobs this week, including technology and operations roles, dow jumps 300 points as wall street grows hopeful that a debt ceiling deal can be reached, nvidia shares jumped 25% this week  and got cheaper. here's how that happens, disney rips desantis bid to disqualify judge in free speech lawsuit, is there a 'right' age for kids to be on social media? here's what an expert says, investors shifted into these gold and small-cap etfs this week, vesting means it can take up to 6 years for workers to own their 401(k) match, a.i. excitement leads to a winning week for nvidia and other tech stocks, despite all odds, consumers are still traveling this summer. how to play it, taylor swift to metallica: top 10 most in-demand artists of summer, companies are learning gen z isnt the easiest generation to work with, club name ford teams up with tesla, sending shares soaring, paramount shares pop after bdt capital bets on the media giant's key shareholder, biden interior advances renewable energy transmission projects in nevada, needham says this stock plays the 'almost perfect marriage' between a.i., crypto, 30-year-old billionaire started with a website, sewing kit and pizza hut salary, why the pause on student loan payments has been a win for public servants, house passes bill blocking student debt forgivenesswhat borrowers need to know, jpmorgan ceo jamie dimon faces deposition in jeffrey epstein lawsuits, how virtual layoffs became the new normal for workplaces, bofa hits spacecraft builder terran orbital with rare double downgrade, heres why it might be time to buy longer-term bonds now, jpmorgan chase cut about 500 jobs this week, including tech and operations roles, how this cmo got comfortable embracing his asian identity at work, facebook-giphy sale shows how fear of regulators is slowing m&a market, apple and nvidia are in my top 5 holdings. am i still diversified enough?, stocks making the biggest moves midday: ford, marvell technology, gap and more, companies add, expand tuition assistance so workers can go back to college]\nindex: []"

# %%
# Remove punctuation
print(lower_case.punctuation)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [45], line 2
#       1 # Remove punctuation
# ----> 2 print(lower_case.punctuation)
#
# AttributeError: 'str' object has no attribute 'punctuation'

# %%
import re

def remove_punctuation(lower_case):
    return re.sub(r'[^\w\s]', '', lower_case)


text_without_punctuation = remove_punctuation(text)
print(text_without_punctuation)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [49], line 7
#       3 def remove_punctuation(lower_case):
#       4     return re.sub(r'[^\w\s]', '', lower_case)
# ----> 7 text_without_punctuation = remove_punctuation(text)
#       8 print(text_without_punctuation)
#
# Cell In [49], line 4, in remove_punctuation(lower_case)
#       3 def remove_punctuation(lower_case):
# ----> 4     return re.sub(r'[^\w\s]', '', lower_case)
#
# File C:\Python3\Lib\re\__init__.py:185, in sub(pattern, repl, string, count, flags)
#     178 def sub(pattern, repl, string, count=0, flags=0):
#     179     """Return the string obtained by replacing the leftmost
#     180     non-overlapping occurrences of the pattern in string by the
#     181     replacement repl.  repl can be either a string or a callable;
#     182     if a string, backslash escapes in it are processed.  If it is
#     183     a callable, it's passed the Match object and must return
#     184     a replacement string to be used."""
# --> 185     return _compile(pattern, flags).sub(repl, string, count)
#
# TypeError: expected string or bytes-like object, got 'DataFrame'
