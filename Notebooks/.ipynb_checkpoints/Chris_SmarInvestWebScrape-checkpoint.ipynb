# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">
#
# # Data Scraping for SmartInvest
#
# - [API Reference]()
# - [Reference](https://www.cnbc.com/)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">

# %% [markdown]
# ### Table of Contents <a class="anchor" id="PSCRAPE_toc"></a>
#
# * [Table of Contents](#PSCRAPE_toc)
#     * [1. Abstract](#PSCRAPE_page_1)
#     * [2. Imported Libraries](#PSCRAPE_page_2)
#     * [3. Import Data](#PSCRAPE_page_3)
#     * [4. Data Compiler](#PSCRAPE_page_4)
#     * [5. Data Collection Automation](#PSCRAPE_page_5)
#     * [6. Checking the Column Names](#PSCRAPE_page_6)
#     * [7. Cleaning the Column Names](#PSCRAPE_page_7)
#     * [8. Creating a new Cleaned Dataset](#PSCRAPE_page_8)
#     * [9. Counting Columns](#PSCRAPE_page_9)
#     * [10. Get Info about the Dataset](#PSCRAPE_page_10)
#     * [11. Get Descriptive Statistics about the Dataset](#PSCRAPE_page_11)
#     * [12. Counting Rows and Removing any NANs](#PSCRAPE_page_12)
#     * [13. Correlation Analysis](#PSCRAPE_page_13)
#     * [14. Principal Component Analysis (PCA)](#PSCRAPE_page_14)
#     * [15. Group Comparison](#PSCRAPE_page_15)
#     * [16. TBD](#PSCRAPE_page_16)
#     * [17. Groupby Function](#PSCRAPE_page_17)

# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">
#
# # Page 1 - Abstract <a class="anchor" id="PSCRAPE_page_1"></a>
#
# [Back to Top](#PSCRAPE_toc)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">

# %% [markdown]
# >This abstract presents the utilization of the BeautifulSoup Python library to web scrape textual data from the CNBC financial news outlet. The scraped data serves as the foundation for developing a sentiment indicator aimed at stock market analysis. By extracting relevant financial news articles and employing sentiment analysis techniques, sentiment scores are assigned to the text, indicating whether the sentiment expressed in the articles is positive, negative, or neutral. These sentiment scores can be aggregated over time to create a sentiment indicator, providing valuable insights into market sentiment and assisting traders and investors in making informed decisions.

# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">
#
# # Page 2 - Imported Libraries<a class="anchor" id="PSCRAPE_page_2"></a>
#
# [Back to Top](#PSCRAPE_toc)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">
#
# # Page 3 - Import Data<a class="anchor" id="PSCRAPE_page_3"></a>
#
# [Back to Top](#PSCRAPE_toc)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">

# %% [markdown]
# ## Primary Headline

# %%
URL = "https://www.cnbc.com/"

# %%
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
# This pulls pulls the URL and Main Headline Data
soup.find('div', class_="FeaturedCard-packagedCardTitle")

# %%
result = soup.find_all('div', class_="FeaturedCard-packagedCardTitle")

# %%
for headline in soup.find_all('div', class_="FeaturedCard-contentText"):
    links = headline.find_all("a")
    for link in links:
        print(link.text.strip())
# Out:
# Biden says he's 'very optimistic' about a debt ceiling deal

# %% [markdown]
# # Secondary Headlines

# %%
import requests
from bs4 import BeautifulSoup

# %%
URL = "https://www.cnbc.com/"

# %%
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
soup.find('div', class_="SecondaryCard-headline")
# Out:
# <div class="SecondaryCard-headline"><a href="https://www.cnbc.com/2023/05/25/stock-market-today-live-updates.html" title="Stocks rally Friday on hopes for a debt ceiling deal, Nasdaq notches fifth straight week of wins">Stocks rally Friday on hopes for a debt ceiling deal, Nasdaq notches fifth straight week of wins</a></div>

# %%
result_secondary = soup.find_all('div', class_="SecondaryCard-headline")

# %%
for headline in soup.find_all('div', class_="SecondaryCard-headline"):
    links = headline.find_all("a")
    for link in links:
        print(link.text.strip())
# Out:
# Stocks rally Friday on hopes for a debt ceiling deal, Nasdaq notches fifth straight week of wins
# The tech trade is back, driven by A.I. craze and prospect of a less aggressive Fed

# %% [markdown]
# # Latest News Headlines

# %%
import requests
from bs4 import BeautifulSoup

# %%
URL = "https://www.cnbc.com/"

# %%
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
soup.find('div', class_="LatestNews-headlineWrapper")
# Out:
# <div class="LatestNews-headlineWrapper"><span class="LatestNews-wrapper"><time class="LatestNews-timestamp">42 Min Ago</time></span><a class="LatestNews-headline" href="https://www.cnbc.com/2023/05/27/how-janie-deegan-built-janies-life-changing-baked-goods.html" title="How Janie Deegan built Janie's Life-Changing Baked Goods">How Janie Deegan built Janie's Life-Changing Baked Goods</a></div>

# %%
result_secondary = soup.find_all('div', class_="LatestNews-headlineWrapper")

# %%
for headline in soup.find_all('div', class_="LatestNews-headlineWrapper"):
    links = headline.find_all("a")
    for link in links:
        print(link.text.strip())
# Out:
# How Janie Deegan built Janie's Life-Changing Baked Goods
# Top 10 cheapest places in the U.S. to buy a beach house
# Mark Cuban calls Elon Musk’s Twitter algorithm unfair—here's how he'd fix it
# 3 investing tips as the federal debt ceiling 'X-date' approaches
# Microsoft keyboard users are ‘devastated’ after discontinuation of accessories
# Steve Adcock: The 3 'stupidest' myths I've heard about early retirement
#
# Chip stocks AMD and Nvidia are among the most overbought stocks on Wall Street
#
# Analysts are pounding the table for these must-own stocks ahead of summer
# Lower-income consumers pay for wealthy's credit card rewards, some economists say
# How Mastercard has outperformed Visa
# Why commercial real estate firms are joining to recruit Black student-athletes
#
# Japan stocks are on fire this year. Why the rally could have 'staying power'
#
# Marvell Technology shares surge after earnings beat. Here's how to play it
# The tech trade is back, driven by A.I. craze and prospect of slowing Fed hikes
#
# Next week hints at only short-lived debt deal relief as jobs report looms
# Treasury says it could run out of money June 5, buying time for debt ceiling talks
# Disney rips DeSantis bid to disqualify judge in free speech lawsuit
# Why the pause on student loan payments has been a win for public servants
# Facebook-Giphy sale shows how fear of regulators is slowing M&A market
# JPMorgan Chase cut about 500 jobs this week, including tech and operations roles
# Is there a 'right' age for kids to be on social media? Here's what an expert says
#
# A.I. excitement leads to a winning week for Nvidia and other tech stocks
#
# Nvidia shares jumped 25% this week — and got cheaper. Here's how that happens
#
# Needham says this stock plays the 'almost perfect marriage' between A.I., crypto
# AI is the latest buzzword in tech—but before investing, know these 4 terms
# Taylor Swift to Metallica: Top 10 most in-demand artists of summer
#
# Investors shifted into these gold and small-cap ETFs this week
# Ford's EV charging deal with Tesla puts pressure on GM, other rival automakers
# Paramount shares pop after BDT Capital bets on the media giant's key shareholder
# Stocks making the biggest moves midday: Ford, Marvell Technology, Gap and more

# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">
#
# # Page 4 - Headline Compiler <a class="anchor" id="PSCRAPE_page_4"></a>
#
# [Back to Top](#PSCRAPE_toc)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">

# %% [markdown]
# # Primary Headline Compiler

# %%
# Automate Collection 
import schedule
import time

import pandas as pd
import csv
import requests
from bs4 import BeautifulSoup
url = "https://www.cnbc.com/"

def append_data_to_csv(url):
    file_path = "../Data/PrimaryHeadline_CV.csv"

    # Fetch the data from the URL
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")

    # Extract the headlines
    headlines = set()
    for headline in soup.find_all('div', class_="FeaturedCard-contentText"):
        links = headline.find_all("a")
        for link in links:
            headlines.add(link.text.strip())

    # Append the data to the CSV file
    with open(file_path, "a", newline="") as file:
        writer = csv.writer(file)

        # Check for duplicates before writing
        existing_headlines = set()
        try:
            with open(file_path, "r") as existing_file:
                existing_data = csv.reader(existing_file)
                for row in existing_data:
                    existing_headlines.update(row)
        except FileNotFoundError:
            pass

        new_headlines = headlines - existing_headlines
        if new_headlines:
            writer.writerow(new_headlines)
            
# Schedule the interval for collection
#schedule.every(2).hours.do(append_data_to_csv, url="https://www.cnbc.com/")


# while True:
    # Example usage
URL = "https://www.cnbc.com/"
append_data_to_csv(URL)

# %%
data_test = pd.read_csv('../Data/PrimaryHeadline_CV.csv')

# %%
data_test
# Out:
#   Debt ceiling negotiators make progress on spending, but still have 'major issues'
# 0  Treasury now says it could run out of money Ju...
# 1  Biden says he's 'very optimistic' about a debt...

# %% [markdown]
# # Secondary Headline Complier

# %%
# Automate Collection 
import schedule
import time

import pandas as pd
import csv
import requests
from bs4 import BeautifulSoup
url = "https://www.cnbc.com/"

def append_data_to_csv(url):
    file_path = "../Data/SecondaryHeadline_CV.csv"

    # Fetch the data from the URL
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")

    # Extract the headlines
    headlines = set()
    for headline in soup.find_all('div', class_="SecondaryCard-headline"):
        links = headline.find_all("a")
        for link in links:
            headlines.add(link.text.strip())

    # Append the data to the CSV file
    with open(file_path, "a", newline="") as file:
        writer = csv.writer(file)

        # Check for duplicates before writing
        existing_headlines = set()
        try:
            with open(file_path, "r") as existing_file:
                existing_data = csv.reader(existing_file)
                for row in existing_data:
                    existing_headlines.update(row)
        except FileNotFoundError:
            pass

        new_headlines = headlines - existing_headlines
        if new_headlines:
            writer.writerow(new_headlines)
            
# Schedule the interval for collection
#schedule.every(2).hours.do(append_data_to_csv, url="https://www.cnbc.com/")


#while True:
    # Example usage
URL = "https://www.cnbc.com/"
append_data_to_csv(URL)

# %%
data_test1 = pd.read_csv('../Data/SecondaryHeadline_CV.csv')

# %%
data_test1
# Out:
#   JPMorgan Chase cut about 500 technology and operations jobs this week, sources say
# 0  JPMorgan Chase cut about 500 jobs this week, i...                                  \
# 1  The tech trade is back, driven by A.I. craze a...
#
#   Dow jumps 300 points as Wall Street grows hopeful that a debt ceiling deal can be reached
# 0                                                NaN
# 1  Stocks rally Friday on hopes for a debt ceilin...

# %% [markdown]
# # Latest News Headline Compiler

# %%
# Latest News Headlines 
import schedule
import time

# NLP Remove stop words
import nltk
from nltk.corpus import stopwords

import pandas as pd
import csv
import requests
from bs4 import BeautifulSoup
url = "https://www.cnbc.com/"

def preprocess_data(data):
    # Apply any necessary preprocessing steps
    # Remove characters not recognized by UTF-8
    data = data.encode('utf-8', errors='ignore').decode('utf-8')
    
    # For example, convert text to lowercase or capitalize the first letter of each word
    return data.lower()

     # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in data.split() if word.lower() not in stop_words]
    data = ' '.join(words)
    return data

def append_data_to_csv(url):
    file_path = "../Data/LatestHeadline_CV.csv"

    # Fetch the data from the URL
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")

    # Extract the headlines
    headlines = set()
    for headline in soup.find_all('div', class_="LatestNews-headlineWrapper"):
        links = headline.find_all("a")
        for link in links:
            headlines.add(link.text.strip())
            
    processed_headlines = [preprocess_data(headline) for headline in headlines]

    # Append the data to the CSV file
    with open(file_path, "a", newline="") as file:
        writer = csv.writer(file)

        # Check for duplicates before writing
        existing_headlines = set()
        try:
            with open(file_path, "r") as existing_file:
                existing_data = csv.reader(existing_file)
                for row in existing_data:
                    existing_headlines.update(row)
        except FileNotFoundError:
            pass

        new_headlines = set(processed_headlines) - set(existing_headlines)
        if new_headlines:
            writer.writerow(new_headlines)
            
# Schedule the interval for collection
#schedule.every(2).hours.do(append_data_to_csv, url="https://www.cnbc.com/")


#while True:
    # Example usage
URL = "https://www.cnbc.com/"
append_data_to_csv(URL)

# %%
data_test2 = pd.read_csv('../Data/LatestHeadline_CV.csv',encoding='latin-1')

# %%
data_test2
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ï»¿
# NaN                                                companies add, expand tuition assistance so wor... stocks making the biggest moves midday: ford, m... despite all odds, consumers are still traveling... marvell shares soar 25% after the chip firm bea... biden interior advances renewable energy transm... apple and nvidia are in my top 5 holdings. am i... companies are learning gen z isnt the easiest ... heres why it might be time to buy longer-term ... house passes bill blocking student debt forgive... paramount shares pop after bdt capital bets on ... ford's ev charging deal with tesla puts pressur... morgan stanley upgrades this  mining stock that... club name ford teams up with tesla, sending sha... bofa hits spacecraft builder terran orbital wit... taylor swift to metallica: top 10 most in-deman... facebook-giphy sale shows how fear of regulator... ai is the latest buzzword in techbut before in... needham says this stock plays the 'almost perfe... jpmorgan chase cut about 500 tech and operation... how virtual layoffs became the new normal for w... nvidia shares jumped 25% this week  and got ch... these industries could face major disruptions f... a.i. excitement leads to a winning week for nvi... vesting means it can take up to 6 years for wor... is there a 'right' age for kids to be on social... jpmorgan ceo jamie dimon faces deposition in je... 30-year-old billionaire started with a website,... why the pause on student loan payments has been... how this cmo got comfortable embracing his asia...  investors shifted into these gold and small-ca...
# jpmorgan chase cut about 500 jobs this week, in... disney rips desantis bid to disqualify judge in... NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                                                               NaN
# top 10 cheapest places in the u.s. to buy a bea... 3 investing tips as the federal debt ceiling 'x... lower-income consumers pay for wealthy's credit... analysts are pounding the table for these must-... how janie deegan built janie's life-changing ba... the tech trade is back, driven by a.i. craze an... chip stocks amd and nvidia are among the most o... why commercial real estate firms are joining to... how mastercard has outperformed visa               mark cuban calls elon musks twitter algorithm ... next week hints at only short-lived debt deal r... steve adcock: the 3 'stupidest' myths i've hear... marvell technology shares surge after earnings ... treasury says it could run out of money june 5,... microsoft keyboard users are devastated after... japan stocks are on fire this year. why the ral... NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                                                               NaN

# %% [markdown]
# # All Headlines Compiler

# %%
import schedule
import time

# NLP Remove stop words
import nltk
from nltk.corpus import stopwords

import pandas as pd
import csv
import requests
from bs4 import BeautifulSoup
url = "https://www.cnbc.com/"

def preprocess_data(data):
    # Apply any necessary preprocessing steps
    # Remove characters not recognized by UTF-8
    data = data.encode('utf-8', errors='ignore').decode('utf-8')
    
    # For example, convert text to lowercase or capitalize the first letter of each word
    return data.lower()

     # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in data.split() if word.lower() not in stop_words]
    data = ' '.join(words)
    return data

def append_data_to_csv(url):
    file_path = "../Data/ConsolidatedHeadline_CV.csv"

    # Fetch the data from the URL
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")

    # Extract the headlines
    headlines = set()
    for headline in soup.find_all('div', class_="FeaturedCard-contentText"):
        links = headline.find_all("a")
        for link in links:
            headlines.add(link.text.strip())

    for headline in soup.find_all('div', class_="SecondaryCard-headline"):
        links = headline.find_all("a")
        for link in links:
            headlines.add(link.text.strip())

    for headline in soup.find_all('div', class_="LatestNews-headlineWrapper"):
        links = headline.find_all("a")
        for link in links:
            headlines.add(link.text.strip())

    # Process the headlines
    processed_headlines = [preprocess_data(headline) for headline in headlines]

    # Filter out null values
    non_null_headlines = [headline for headline in processed_headlines if headline]
    
    # Append the data to the CSV file
    with open(file_path, "a", newline="") as file:
        writer = csv.writer(file)

        # Check for duplicates before writing
        existing_headlines = set()
        try:
            with open(file_path, "r") as existing_file:
                existing_data = csv.reader(existing_file)
                for row in existing_data:
                    existing_headlines.update(row)
        except FileNotFoundError:
            pass

        new_headlines = set(processed_headlines) - set(existing_headlines)
        if new_headlines:
            writer.writerow(new_headlines)

            
# Schedule the interval for collection
#schedule.every(2).hours.do(append_data_to_csv, url="https://www.cnbc.com/")


#while True:
    # Example usage
URL = "https://www.cnbc.com/"
append_data_to_csv(URL)

# %%
data_test3 = pd.read_csv('../Data/ConsolidatedHeadline_CV.csv',encoding='latin-1')

# %%
data_test3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ï»¿
# NaN                                                debt ceiling negotiators make progress on spend... morgan stanley upgrades this  mining stock that... ai is the latest buzzword in techbut before in... ford's ev charging deal with tesla puts pressur... marvell shares soar 25% after the chip firm bea... jpmorgan chase cut about 500 jobs this week, in... dow jumps 300 points as wall street grows hopef... nvidia shares jumped 25% this week  and got ch... disney rips desantis bid to disqualify judge in... is there a 'right' age for kids to be on social... investors shifted into these gold and small-cap... vesting means it can take up to 6 years for wor... a.i. excitement leads to a winning week for nvi... despite all odds, consumers are still traveling... taylor swift to metallica: top 10 most in-deman... companies are learning gen z isnt the easiest ... club name ford teams up with tesla, sending sha... paramount shares pop after bdt capital bets on ... biden interior advances renewable energy transm... needham says this stock plays the 'almost perfe... 30-year-old billionaire started with a website,... why the pause on student loan payments has been... house passes bill blocking student debt forgive... jpmorgan ceo jamie dimon faces deposition in je... how virtual layoffs became the new normal for w... bofa hits spacecraft builder terran orbital wit... heres why it might be time to buy longer-term ... jpmorgan chase cut about 500 jobs this week, in... how this cmo got comfortable embracing his asia... facebook-giphy sale shows how fear of regulator... apple and nvidia are in my top 5 holdings. am i... stocks making the biggest moves midday: ford, m...  companies add, expand tuition assistance so wo...
# stocks rally friday on hopes for a debt ceiling... NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                                                               NaN
# treasury says it could run out of money june 5,... next week hints at only short-lived debt deal r... the tech trade is back, driven by a.i. craze an... the tech trade is back, driven by a.i. craze an... treasury now says it could run out of money jun... marvell shares soar 32% after the chip firm bea... NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                                                               NaN
# top 10 cheapest places in the u.s. to buy a bea... 3 investing tips as the federal debt ceiling 'x... lower-income consumers pay for wealthy's credit... analysts are pounding the table for these must-... how janie deegan built janie's life-changing ba... chip stocks amd and nvidia are among the most o... why commercial real estate firms are joining to... how mastercard has outperformed visa               biden says he's 'very optimistic' about a debt ... mark cuban calls elon musks twitter algorithm ... steve adcock: the 3 'stupidest' myths i've hear... marvell technology shares surge after earnings ... microsoft keyboard users are devastated after... japan stocks are on fire this year. why the ral... NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                NaN                                                                                               NaN

# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">
#
# # Page 5 - Data Collection Automation <a class="anchor" id="PSCRAPE_page_5"></a>
#
# [Back to Top](#PSCRAPE_toc)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumAquamarine">

# %%
pip install jupyter_scheduler
# Out:
# Collecting jupyter_scheduler
#   Downloading jupyter_scheduler-1.3.2-py3-none-any.whl (516 kB)
#                                               0.0/516.0 kB ? eta -:--:--
#      -----                                   71.7/516.0 kB 1.3 MB/s eta 0:00:01
#      ----------------                       225.3/516.0 kB 2.3 MB/s eta 0:00:01
#      -------------------------------------  512.0/516.0 kB 3.6 MB/s eta 0:00:01
#      -------------------------------------- 516.0/516.0 kB 3.2 MB/s eta 0:00:00
# Collecting croniter (from jupyter_scheduler)
#   Downloading croniter-1.3.15-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: fsspec in c:\python3\lib\site-packages (from jupyter_scheduler) (2023.3.0)
# Requirement already satisfied: jupyter-server<3,>=1.6 in c:\python3\lib\site-packages (from jupyter_scheduler) (1.23.3)
# Requirement already satisfied: nbconvert in c:\python3\lib\site-packages (from jupyter_scheduler) (7.2.5)
# Requirement already satisfied: psutil in c:\python3\lib\site-packages (from jupyter_scheduler) (5.9.4)
# Collecting pydantic (from jupyter_scheduler)
#   Downloading pydantic-1.10.8-cp311-cp311-win_amd64.whl (2.1 MB)
#                                               0.0/2.1 MB ? eta -:--:--
#      --------------                           0.8/2.1 MB 16.7 MB/s eta 0:00:01
#      -----------------------------------      1.9/2.1 MB 20.0 MB/s eta 0:00:01
#      ---------------------------------------  2.1/2.1 MB 16.6 MB/s eta 0:00:01
#      ---------------------------------------- 2.1/2.1 MB 14.9 MB/s eta 0:00:00
# Requirement already satisfied: pytz in c:\python3\lib\site-packages (from jupyter_scheduler) (2022.6)
# Collecting s3fs (from jupyter_scheduler)
#   Downloading s3fs-2023.5.0-py3-none-any.whl (28 kB)
# Collecting sqlalchemy<2 (from jupyter_scheduler)
#   Downloading SQLAlchemy-1.4.48-cp311-cp311-win_amd64.whl (1.6 MB)
#                                               0.0/1.6 MB ? eta -:--:--
#      ---------------------------              1.1/1.6 MB 34.7 MB/s eta 0:00:01
#      ---------------------------------------- 1.6/1.6 MB 25.4 MB/s eta 0:00:00
# Requirement already satisfied: traitlets in c:\python3\lib\site-packages (from jupyter_scheduler) (5.5.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\python3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (3.6.2)
# Requirement already satisfied: argon2-cffi in c:\python3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (21.3.0)
# Requirement already satisfied: jinja2 in c:\python3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (3.1.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\python3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (7.4.7)
# Requirement already satisfied: jupyter-core>=4.7.0 in c:\python3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (5.0.0)
# Requirement already satisfied: nbformat>=5.2.0 in c:\python3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (5.7.0)
# Requirement already satisfied: packaging in c:\python3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (21.3)
# Requirement already satisfied: prometheus-client in c:\python3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (0.15.0)
# Requirement already satisfied: pyzmq>=17 in c:\python3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (24.0.1)
# Requirement already satisfied: Send2Trash in c:\python3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\python3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (0.17.0)
# Requirement already satisfied: tornado>=6.1.0 in c:\python3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (6.2)
# Requirement already satisfied: websocket-client in c:\python3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (1.4.2)
# Requirement already satisfied: pywinpty in c:\python3\lib\site-packages (from jupyter-server<3,>=1.6->jupyter_scheduler) (2.0.9)
# Requirement already satisfied: beautifulsoup4 in c:\python3\lib\site-packages (from nbconvert->jupyter_scheduler) (4.11.1)
# Requirement already satisfied: bleach in c:\python3\lib\site-packages (from nbconvert->jupyter_scheduler) (5.0.1)
# Requirement already satisfied: defusedxml in c:\python3\lib\site-packages (from nbconvert->jupyter_scheduler) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\python3\lib\site-packages (from nbconvert->jupyter_scheduler) (0.2.2)
# Requirement already satisfied: markupsafe>=2.0 in c:\python3\lib\site-packages (from nbconvert->jupyter_scheduler) (2.1.1)
# Requirement already satisfied: mistune<3,>=2.0.3 in c:\python3\lib\site-packages (from nbconvert->jupyter_scheduler) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\python3\lib\site-packages (from nbconvert->jupyter_scheduler) (0.7.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\python3\lib\site-packages (from nbconvert->jupyter_scheduler) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\python3\lib\site-packages (from nbconvert->jupyter_scheduler) (2.13.0)
# Requirement already satisfied: tinycss2 in c:\python3\lib\site-packages (from nbconvert->jupyter_scheduler) (1.2.1)
# Collecting greenlet!=0.4.17 (from sqlalchemy<2->jupyter_scheduler)
#   Downloading greenlet-2.0.2-cp311-cp311-win_amd64.whl (192 kB)
#                                               0.0/192.5 kB ? eta -:--:--
#      ------------------------------------- 192.5/192.5 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in c:\python3\lib\site-packages (from croniter->jupyter_scheduler) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\python3\lib\site-packages (from pydantic->jupyter_scheduler) (4.5.0)
# Collecting aiobotocore~=2.5.0 (from s3fs->jupyter_scheduler)
#   Downloading aiobotocore-2.5.0-py3-none-any.whl (72 kB)
#                                               0.0/72.7 kB ? eta -:--:--
#      ---------------------------------------- 72.7/72.7 kB ? eta 0:00:00
# Collecting fsspec (from jupyter_scheduler)
#   Downloading fsspec-2023.5.0-py3-none-any.whl (160 kB)
#                                               0.0/160.1 kB ? eta -:--:--
#      ------------------------------------- 160.1/160.1 kB 10.0 MB/s eta 0:00:00
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from s3fs->jupyter_scheduler)
#   Downloading aiohttp-3.8.4-cp311-cp311-win_amd64.whl (317 kB)
#                                               0.0/317.2 kB ? eta -:--:--
#      ------------------------------------- 317.2/317.2 kB 19.2 MB/s eta 0:00:00
# Collecting botocore<1.29.77,>=1.29.76 (from aiobotocore~=2.5.0->s3fs->jupyter_scheduler)
#   Downloading botocore-1.29.76-py3-none-any.whl (10.4 MB)
#                                               0.0/10.4 MB ? eta -:--:--
#      ------                                   1.7/10.4 MB 52.5 MB/s eta 0:00:01
#      --------------                           3.8/10.4 MB 47.4 MB/s eta 0:00:01
#      ----------------                         4.2/10.4 MB 33.8 MB/s eta 0:00:01
#      -------------------------                6.6/10.4 MB 38.3 MB/s eta 0:00:01
#      -------------------------                6.7/10.4 MB 35.5 MB/s eta 0:00:01
#      -----------------------------------      9.1/10.4 MB 34.3 MB/s eta 0:00:01
#      ------------------------------------     9.4/10.4 MB 31.5 MB/s eta 0:00:01
#      --------------------------------------  10.4/10.4 MB 31.1 MB/s eta 0:00:01
#      --------------------------------------- 10.4/10.4 MB 28.4 MB/s eta 0:00:00
# Collecting wrapt>=1.10.10 (from aiobotocore~=2.5.0->s3fs->jupyter_scheduler)
#   Downloading wrapt-1.15.0-cp311-cp311-win_amd64.whl (36 kB)
# Collecting aioitertools>=0.5.1 (from aiobotocore~=2.5.0->s3fs->jupyter_scheduler)
#   Downloading aioitertools-0.11.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\python3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->jupyter_scheduler) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\python3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->jupyter_scheduler) (2.1.1)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->jupyter_scheduler)
#   Downloading multidict-6.0.4-cp311-cp311-win_amd64.whl (28 kB)
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->jupyter_scheduler)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->jupyter_scheduler)
#   Downloading yarl-1.9.2-cp311-cp311-win_amd64.whl (60 kB)
#                                               0.0/60.2 kB ? eta -:--:--
#      ---------------------------------------- 60.2/60.2 kB 3.3 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->jupyter_scheduler)
#   Downloading frozenlist-1.3.3-cp311-cp311-win_amd64.whl (32 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->jupyter_scheduler)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: idna>=2.8 in c:\python3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.6->jupyter_scheduler) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\python3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.6->jupyter_scheduler) (1.3.0)
# Requirement already satisfied: entrypoints in c:\python3\lib\site-packages (from jupyter-client>=6.1.12->jupyter-server<3,>=1.6->jupyter_scheduler) (0.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in c:\python3\lib\site-packages (from jupyter-client>=6.1.12->jupyter-server<3,>=1.6->jupyter_scheduler) (1.5.6)
# Requirement already satisfied: platformdirs in c:\python3\lib\site-packages (from jupyter-core>=4.7.0->jupyter-server<3,>=1.6->jupyter_scheduler) (2.5.4)
# Requirement already satisfied: pywin32>=1.0 in c:\python3\lib\site-packages (from jupyter-core>=4.7.0->jupyter-server<3,>=1.6->jupyter_scheduler) (305)
# Requirement already satisfied: fastjsonschema in c:\python3\lib\site-packages (from nbformat>=5.2.0->jupyter-server<3,>=1.6->jupyter_scheduler) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\python3\lib\site-packages (from nbformat>=5.2.0->jupyter-server<3,>=1.6->jupyter_scheduler) (4.17.0)
# Requirement already satisfied: six>=1.5 in c:\python3\lib\site-packages (from python-dateutil->croniter->jupyter_scheduler) (1.16.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\python3\lib\site-packages (from argon2-cffi->jupyter-server<3,>=1.6->jupyter_scheduler) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\python3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter_scheduler) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\python3\lib\site-packages (from bleach->nbconvert->jupyter_scheduler) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\python3\lib\site-packages (from packaging->jupyter-server<3,>=1.6->jupyter_scheduler) (3.0.9)
# Collecting jmespath<2.0.0,>=0.7.1 (from botocore<1.29.77,>=1.29.76->aiobotocore~=2.5.0->s3fs->jupyter_scheduler)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\python3\lib\site-packages (from botocore<1.29.77,>=1.29.76->aiobotocore~=2.5.0->s3fs->jupyter_scheduler) (1.26.12)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\python3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.2.0->jupyter-server<3,>=1.6->jupyter_scheduler) (0.19.2)
# Requirement already satisfied: cffi>=1.0.1 in c:\python3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.6->jupyter_scheduler) (1.15.1)
# Requirement already satisfied: pycparser in c:\python3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.6->jupyter_scheduler) (2.21)
# Installing collected packages: wrapt, pydantic, multidict, jmespath, greenlet, fsspec, frozenlist, async-timeout, aioitertools, yarl, sqlalchemy, croniter, botocore, aiosignal, aiohttp, aiobotocore, s3fs, jupyter_scheduler
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.3.0
#     Uninstalling fsspec-2023.3.0:
#       Successfully uninstalled fsspec-2023.3.0
# Successfully installed aiobotocore-2.5.0 aiohttp-3.8.4 aioitertools-0.11.0 aiosignal-1.3.1 async-timeout-4.0.2 botocore-1.29.76 croniter-1.3.15 frozenlist-1.3.3 fsspec-2023.5.0 greenlet-2.0.2 jmespath-1.0.1 jupyter_scheduler-1.3.2 multidict-6.0.4 pydantic-1.10.8 s3fs-2023.5.0 sqlalchemy-1.4.48 wrapt-1.15.0 yarl-1.9.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# Automate Collection 
import schedule
import time

# NLP Remove stop words
import nltk
from nltk.corpus import stopwords

import pandas as pd
import csv
import requests
from bs4 import BeautifulSoup
url = "https://www.cnbc.com/"

def preprocess_data(data):
    # Apply any necessary preprocessing steps
    # Remove characters not recognized by UTF-8
    data = data.encode('utf-8', errors='ignore').decode('utf-8')
    
    # For example, convert text to lowercase or capitalize the first letter of each word
    return data.lower()

     # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in data.split() if word.lower() not in stop_words]
    data = ' '.join(words)
    return data

def append_data_to_csv(url):
    file_path = "../Data/ConsolidatedHeadline_CV.csv"

    # Fetch the data from the URL
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")

    # Extract the headlines
    headlines = set()
    for headline in soup.find_all('div', class_="FeaturedCard-contentText"):
        links = headline.find_all("a")
        for link in links:
            headlines.add(link.text.strip())

    for headline in soup.find_all('div', class_="SecondaryCard-headline"):
        links = headline.find_all("a")
        for link in links:
            headlines.add(link.text.strip())

    for headline in soup.find_all('div', class_="LatestNews-headlineWrapper"):
        links = headline.find_all("a")
        for link in links:
            headlines.add(link.text.strip())

    # Process the headlines
    processed_headlines = [preprocess_data(headline) for headline in headlines]

    # Append the data to the CSV file
    with open(file_path, "a", newline="") as file:
        writer = csv.writer(file)

        # Check for duplicates before writing
        existing_headlines = set()
        try:
            with open(file_path, "r") as existing_file:
                existing_data = csv.reader(existing_file)
                for row in existing_data:
                    existing_headlines.update(row)
        except FileNotFoundError:
            pass

        new_headlines = set(processed_headlines) - set(existing_headlines)
        if new_headlines:
            writer.writerow(new_headlines)

            
# Schedule the interval for collection
#schedule.every(2).hours.do(append_data_to_csv, url="https://www.cnbc.com/")


#while True:
    # Example usage
URL = "https://www.cnbc.com/"
append_data_to_csv(URL)
